# %%
import random
from music21 import stream, note, meter, key, tempo

def generate_random_melody(length=16, key_signature='D', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    non_key_degrees = [8, 9, 10, 11, 12]

    # Generate a random melody using scale degrees
    for _ in range(length):
        is_diatonic = random.choice([True, False])  # Randomly choose whether to use diatonic or non-key tone

        if is_diatonic:
            degree = random.choice(diatonic_degrees)
        else:
            degree = random.choice(non_key_degrees)

        octave = random.choice(range(3, 6))  # Choose an octave

        # Convert the scale degree to the corresponding diatonic or non-key tone
        scale = key.Key(key_signature).getScale('minor')
        print(scale.getPitches())
        if is_diatonic:
            pitch_class = scale.getPitches()[degree - 1].name
        else:
            pitch_class = scale.getPitches()[degree - 8].name

      

        melody_part.append(note.Note(pitch_class, quarterLength=0.5))

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
# [<music21.pitch.Pitch B4>, <music21.pitch.Pitch C#5>, <music21.pitch.Pitch D5>, <music21.pitch.Pitch E5>, <music21.pitch.Pitch F#5>, <music21.pitch.Pitch G5>, <music21.pitch.Pitch A5>, <music21.pitch.Pitch B5>]
# [<music21.pitch.Pitch B4>, <music21.pitch.Pitch C#5>, <music21.pitch.Pitch D5>, <music21.pitch.Pitch E5>, <music21.pitch.Pitch F#5>, <music21.pitch.Pitch G5>, <music21.pitch.Pitch A5>, <music21.pitch.Pitch B5>]
# [<music21.pitch.Pitch B4>, <music21.pitch.Pitch C#5>, <music21.pitch.Pitch D5>, <music21.pitch.Pitch E5>, <music21.pitch.Pitch F#5>, <music21.pitch.Pitch G5>, <music21.pitch.Pitch A5>, <music21.pitch.Pitch B5>]
# [<music21.pitch.Pitch B4>, <music21.pitch.Pitch C#5>, <music21.pitch.Pitch D5>, <music21.pitch.Pitch E5>, <music21.pitch.Pitch F#5>, <music21.pitch.Pitch G5>, <music21.pitch.Pitch A5>, <music21.pitch.Pitch B5>]
# ...

# %%
import random
from music21 import stream, note, meter, key, tempo

keyNotes = [1,3,5,6]
nonKeyNotes = [2,4]

def generate_random_melody(length=125, key_signature='C', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Generate a random melody using scale degrees
    for _ in range(length):
        is_diatonic = random.choice([True, False])  # Randomly choose whether to use diatonic or non-key tone

        if is_diatonic:
            degree = random.choice(keyNotes)  # Choose a diatonic scale degree
        else:
            degree = random.choice(nonKeyNotes)  # Choose any scale degree

        octave = random.choice(range(1, 6))  # Choose an octave

        # Convert the scale degree to the corresponding diatonic or non-key tone
        scale = key.Key(key_signature).getScale()
        print(scale)
        pitch_class = scale.getPitches()[degree - 1].nameWithOctave 
        print(pitch_class)
        # Include accidental information
        accidental = random.choice(["", "sharp", "flat", "natural"])
        pitch_class_with_accidental = pitch_class + accidental

        note_obj = note.Note(pitch_class_with_accidental, quarterLength=0.5)

        # Add "nt" as a lyric below non-diatonic notes and color it red
        if not is_diatonic:
            lyric = note.Lyric("nt")
            lyric.style.color = 'red'
            note_obj.lyrics.append(lyric)

        melody_part.append(note_obj)

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
# Out:
# <music21.scale.MajorScale C major>
# G4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# G4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# A4
# <music21.scale.MajorScale C major>
# E4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# C4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# G4
# <music21.scale.MajorScale C major>
# C4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# G4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# F4
# <music21.scale.MajorScale C major>
# E4
# <music21.scale.MajorScale C major>
# D4
# <music21.scale.MajorScale C major>
# D4
# ...

# %%
import random
from music21 import stream, note, meter, key, tempo

def generate_random_melody(length=16, key_signature='D', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    non_key_degrees = [8, 9, 10, 11, 12]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Generate a random melody using scale degrees
    motif = []
    for _ in range(length):
        # Introduce motivic development by repeating and transforming motifs
        if len(motif) > 0 and random.random() < 0.3:
            for motif_note in motif:
                new_note = note.Note(motif_note.name, quarterLength=motif_note.quarterLength)
                melody_part.append(new_note)
        else:
            is_diatonic = random.choice([True, False])
            if is_diatonic:
                degree = random.choice(diatonic_degrees)
            else:
                degree = random.choice(non_key_degrees)

            octave = random.choice(range(3, 6))

            scale = key.Key(key_signature).getScale('minor')
            if is_diatonic:
                pitch_class = scale.getPitches()[degree - 1].name
            else:
                pitch_class = scale.getPitches()[degree - 8].name

            # Introduce rests to create rhythmic variety
            if random.random() < 0.2:
                melody_part.append(note.Rest(quarterLength=random.choice(note_durations)))
            else:
                new_note = note.Note(pitch_class, quarterLength=random.choice(note_durations))
                melody_part.append(new_note)
                motif.append(new_note)

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv609"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv609_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv609");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv609_play, 2000);
#         } else {
#             midiPlayerDiv609_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo

def generate_random_melody(length=16, key_signature='D', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    non_key_degrees = [8, 9, 10, 11, 12]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Define pre-determined motives
    motive1 = [1, 2, 3, 4]
    motive2 = [5, 6, 7, 8]
    motives = [motive1, motive2]

    # Generate a random melody using predefined motives
    for _ in range(length):
        # Introduce motives
        if random.random() < 0.3:
            motive = random.choice(motives)
            for degree in motive:
                is_diatonic = degree in diatonic_degrees
                octave = random.choice(range(3, 6))

                scale = key.Key(key_signature).getScale('minor')
                if is_diatonic:
                    pitch_class = scale.getPitches()[degree - 1].name
                else:
                    pitch_class = scale.getPitches()[degree - 8].name

                melody_part.append(note.Note(pitch_class, quarterLength=random.choice(note_durations)))
        else:
            # Generate random notes
            is_diatonic = random.choice([True, False])
            degree = random.choice(diatonic_degrees) if is_diatonic else random.choice(non_key_degrees)
            octave = random.choice(range(3, 6))

            scale = key.Key(key_signature).getScale('minor')
            if is_diatonic:
                pitch_class = scale.getPitches()[degree - 1].name
            else:
                pitch_class = scale.getPitches()[degree - 8].name

            melody_part.append(note.Note(pitch_class, quarterLength=random.choice(note_durations)))

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv1872"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv1872_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv1872");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv1872_play, 2000);
#         } else {
#             midiPlayerDiv1872_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo

def generate_random_melody(length=32, key_signature='D', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    non_key_degrees = [8, 9, 10, 11, 12]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Define pre-determined motives
    motive1 = [1, 2, 3, 4]
    motive2 = [5, 6, 7, 8]
    motives = [motive1, motive2]

    # Generate a random melody using predefined motives
    for _ in range(length):
        # Introduce motives
        if random.random() < 0.3:
            motive = random.choice(motives)
            for degree in motive:
                is_diatonic = degree in diatonic_degrees
                octave = random.choice(range(3, 6))

                scale = key.Key(key_signature).getScale('minor')
                if is_diatonic:
                    pitch_class = scale.getPitches()[degree - 1].name
                else:
                    pitch_class = scale.getPitches()[degree - 8].name

                # Choose note duration based on on-beat/off-beat position
                if random.random() < 0.6:
                    duration = random.choice([0.5, 1.0])  # On-beat
                else:
                    duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

                melody_part.append(note.Note(pitch_class, quarterLength=duration))
        else:
            # Generate random notes
            is_diatonic = random.choice([True, False])
            degree = random.choice(diatonic_degrees) if is_diatonic else random.choice(non_key_degrees)
            octave = random.choice(range(3, 6))

            scale = key.Key(key_signature).getScale('minor')
            if is_diatonic:
                pitch_class = scale.getPitches()[degree - 1].name
            else:
                pitch_class = scale.getPitches()[degree - 8].name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

            melody_part.append(note.Note(pitch_class, quarterLength=duration))

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv2779"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv2779_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv2779");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv2779_play, 2000);
#         } else {
#             midiPlayerDiv2779_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo

def generate_random_melody(length=32, key_signature='D', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    melody_part.append(key.Key(key_signature))
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    non_key_degrees = [8, 9, 10, 11, 12]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Define pre-determined motives
    motive1 = [1, 2, 3, 4]
    motive2 = [5, 6, 7, 8]
    motives = [motive1, motive2]

    # Generate a random melody using predefined motives
    for _ in range(length):
        # Introduce motives
        if random.random() < 0.3:
            motive = random.choice(motives)
            for degree in motive:
                is_diatonic = degree in diatonic_degrees
                octave = random.choice(range(3, 6))

                scale = key.Key(key_signature).getScale('minor')
                if is_diatonic:
                    pitch_class = scale.getPitches()[degree - 1].name
                else:
                    pitch_class = scale.getPitches()[degree - 8].name

                # Choose note duration based on on-beat/off-beat position
                if random.random() < 0.6:
                    duration = random.choice([0.5, 1.0])  # On-beat
                else:
                    duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

                melody_part.append(note.Note(pitch_class, quarterLength=duration))
        else:
            # Generate random notes including passing and neighboring tones
            is_diatonic = random.choice([True, False])
            degree = random.choice(diatonic_degrees) if is_diatonic else random.choice(non_key_degrees)
            octave = random.choice(range(3, 6))

            scale = key.Key(key_signature).getScale('minor')
            if is_diatonic:
                pitch_class = scale.getPitches()[degree - 1].name
            else:
                pitch_class = scale.getPitches()[degree - 8].name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

            # Introduce passing or neighboring tones with a probability
            if random.random() < 0.3:
                passing_tone_degree = degree + random.choice([-1, 1])
                passing_tone_degree = max(1, min(passing_tone_degree, 7))  # Ensure within diatonic range
                passing_tone_pitch = scale.getPitches()[passing_tone_degree - 1].name
                melody_part.append(note.Note(passing_tone_pitch, quarterLength=duration * 0.5))
                melody_part.append(note.Note(pitch_class, quarterLength=duration * 0.5))
            elif random.random() < 0.3:
                neighboring_tone_degree = degree + random.choice([-1, 1])
                neighboring_tone_degree = max(1, min(neighboring_tone_degree, 7))  # Ensure within diatonic range
                neighboring_tone_pitch = scale.getPitches()[neighboring_tone_degree - 1].name
                melody_part.append(note.Note(neighboring_tone_pitch, quarterLength=duration * 0.25))
                melody_part.append(note.Note(pitch_class, quarterLength=duration * 0.5))
                melody_part.append(note.Note(neighboring_tone_pitch, quarterLength=duration * 0.25))
            else:
                melody_part.append(note.Note(pitch_class, quarterLength=duration))

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv6066"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv6066_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv6066");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv6066_play, 2000);
#         } else {
#             midiPlayerDiv6066_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo, roman

def generate_random_melody(length=32, key_signature='C', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    key_obj = key.Key(key_signature)
    melody_part.append(key_obj)
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Choose the initial chord (I or IV)
    initial_chord_roman = random.choice(['I', 'IV'])
    current_chord = roman.RomanNumeral(initial_chord_roman, key_obj)

    # Generate a random melody using predefined motives
    for bar in range(length // 4):
        # Generate melody notes for the current bar based on the selected chord
        for _ in range(4):
            # Generate a random note within the current chord
            degree = random.choice(diatonic_degrees)
            chord_pitches = current_chord.pitches[:-1]  # Exclude the octave
            pitch_class = random.choice(chord_pitches).name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

            melody_part.append(note.Note(pitch_class, quarterLength=duration))

        # Update the chord for the next bar (can be the same or different)
        current_chord_roman = random.choice(['I', 'IV'])
        current_chord = roman.RomanNumeral(current_chord_roman, key_obj)

    # Add Roman numerals to the score
    for bar in range(length // 4):
        current_chord_roman = random.choice(['I', 'IV'])
        melody_part.append(roman.RomanNumeral(current_chord_roman, key_obj))

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv7350"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv7350_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv7350");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv7350_play, 2000);
#         } else {
#             midiPlayerDiv7350_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo, roman

def generate_random_melody(length=32, key_signature='C', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    key_obj = key.Key(key_signature)
    melody_part.append(key_obj)
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Choose the initial chord (I or IV)
    initial_chord_roman = random.choice(['I', 'IV'])
    current_chord = roman.RomanNumeral(initial_chord_roman, key_obj)

    # Generate a random melody using predefined motives
    for bar in range(length // 4):
        # Add Roman numeral to the score
        melody_part.append(current_chord)

        # Generate melody notes for the current bar based on the selected chord
        for _ in range(4):
            # Generate a random note within the current chord
            degree = random.choice(diatonic_degrees)
            chord_pitches = current_chord.pitches[:-1]  # Exclude the octave
            pitch_class = random.choice(chord_pitches).name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

            melody_part.append(note.Note(pitch_class, quarterLength=duration))

        # Update the chord for the next bar (can be the same or different)
        current_chord_roman = random.choice(['I', 'IV'])
        current_chord = roman.RomanNumeral(current_chord_roman, key_obj)

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv8642"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv8642_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv8642");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv8642_play, 2000);
#         } else {
#             midiPlayerDiv8642_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo, roman

def generate_random_melody(length=32, key_signature='C', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody
    melody_stream = stream.Score()

    # Add a part to the stream
    melody_part = stream.Part()
    melody_stream.append(melody_part)

    # Set the key and time signature
    key_obj = key.Key(key_signature)
    melody_part.append(key_obj)
    melody_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees and non-key scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]

    # Define possible note durations
    note_durations = [0.25, 0.5, 0.75, 1.0]

    # Choose the initial chord (I or IV)
    initial_chord_roman = random.choice(['I', 'II','III','IV', 'V','VI','VII'])
    current_chord = roman.RomanNumeral(initial_chord_roman, key_obj)

    # Generate a random melody using predefined motives
    for bar in range(length // 4):
        # Generate melody notes for the current bar based on the selected chord
        for _ in range(4):
            # Generate a random note within the current chord
            degree = random.choice(diatonic_degrees)
            chord_pitches = current_chord.pitches[:-1]  # Exclude the octave
            pitch_class = random.choice(chord_pitches).name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 0.75])  # Off-beat

            note_obj = note.Note(pitch_class, quarterLength=duration)
            note_obj.lyric = str(current_chord.figure)
            melody_part.append(note_obj)

        # Update the chord for the next bar (can be the same or different)
        current_chord_roman = random.choice(['I', 'II','III','IV', 'V','VI','VII'])
        current_chord = roman.RomanNumeral(current_chord_roman, key_obj)

    return melody_stream

if __name__ == "__main__":
    random_melody = generate_random_melody()

    # Show the random melody
    random_melody.show()
    random_melody.show("midi")
# Out:
#         <div id="midiPlayerDiv10050"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv10050_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv10050");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv10050_play, 2000);
#         } else {
#             midiPlayerDiv10050_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo, roman

def generate_random_melody_with_chords(length=32, key_signature='C', time_signature='4/4', tempo_mark=120):
    # Create a stream for the melody and chords
    score = stream.Score()

    # Melody part
    melody_part = stream.Part()
    score.append(melody_part)

    # Chords part
    chords_part = stream.Part()
    score.append(chords_part)

    # Set the key and time signature
    key_obj = key.Key(key_signature)
    melody_part.append(key_obj)
    melody_part.append(meter.TimeSignature(time_signature))
    chords_part.append(key_obj)
    chords_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))
    chords_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]

    # Choose the initial chord (I or IV)
    initial_chord_roman = random.choice(['I', 'IV'])
    current_chord = roman.RomanNumeral(initial_chord_roman, key_obj,quarterLength=4.0)

    # Generate a random melody and chords using predefined motives
    for bar in range(length // 4):
        # Generate chords for the current bar
        chords_part.append(current_chord)
        lyric = note.Lyric(roman.romanNumeralFromChord(current_chord, key_obj).figure)
        lyric.style.color = 'red'
        current_chord.lyrics.append(lyric)



        # Generate melody notes for the current bar based on the selected chord
        for _ in range(4):
            
            # Generate a random note within the current chord for the melody
            degree = random.choice(diatonic_degrees)
            chord_pitches = current_chord.pitches[:-1]  # Exclude the octave
            pitch_class = random.choice(chord_pitches).name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 2.0])  # Off-beat

            note_obj = note.Note(pitch_class, quarterLength=duration)
            melody_part.append(note_obj)

        # Update the chord for the next bar (can be the same or different)
        current_chord_roman = random.choice(['I', 'IV'])
        current_chord = roman.RomanNumeral(current_chord_roman, key_obj,quarterLength=4.0)

    return score

if __name__ == "__main__":
    random_melody_with_chords = generate_random_melody_with_chords()

    # Show the random melody with chords
    random_melody_with_chords.show()
    random_melody_with_chords.show("midi")
# Out:
#         <div id="midiPlayerDiv19006"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv19006_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv19006");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv19006_play, 2000);
#         } else {
#             midiPlayerDiv19006_play();
#         }
#         </script>

# %%
import random
from music21 import stream, note, meter, key, tempo, roman

def generate_random_melody_with_chords(length=32, key_signature='C', time_signature='4/4', tempo_mark=360):
    # Create a stream for the melody and chords
    score = stream.Score()

    # Melody part
    melody_part = stream.Part()
    score.append(melody_part)

    # Chords part
    chords_part = stream.Part()
    score.append(chords_part)

    # Set the key and time signature
    key_obj = key.Key(key_signature)
    melody_part.append(key_obj)
    melody_part.append(meter.TimeSignature(time_signature))
    chords_part.append(key_obj)
    chords_part.append(meter.TimeSignature(time_signature))

    # Set the tempo
    melody_part.append(tempo.MetronomeMark(number=tempo_mark))
    chords_part.append(tempo.MetronomeMark(number=tempo_mark))

    # Define diatonic scale degrees
    diatonic_degrees = [1, 2, 3, 4, 5, 6, 7]
    mchords = [
    'i', 'i6', 'i64',
    'ii°', 'iiø43', 'iiø65',
    'III', 'III64',
    'iv', 'iv6', 'iv64',
    'v', 'v6', 'v64',
    'VI', 'VI6', 'VI64',
    'VII', 'VII6', 'VII64'
]
    # Choose the initial chord (I or IV)
    initial_chord_roman = random.choice(mchords)
    current_chord = roman.RomanNumeral(initial_chord_roman, key_obj,quarterLength=4.0)

    # Generate a random melody and chords using predefined motives
    for bar in range(length // 4):
        # Generate chords for the current bar
        chords_part.append(current_chord)
        lyric = note.Lyric(roman.romanNumeralFromChord(current_chord, key_obj).figure)
        lyric.style.color = 'red'
        current_chord.lyrics.append(lyric)



        # Generate melody notes for the current bar based on the selected chord
        for _ in range(4):
            
            # Generate a random note within the current chord for the melody
            degree = random.choice(diatonic_degrees)
            chord_pitches = current_chord.pitches[:-1]  # Exclude the octave
            pitch_class = random.choice(chord_pitches).name

            # Choose note duration based on on-beat/off-beat position
            if random.random() < 0.6:
                duration = random.choice([0.5, 1.0])  # On-beat
            else:
                duration = random.choice([0.25, 0.5, 2.0])  # Off-beat

            note_obj = note.Note(pitch_class, quarterLength=duration)
            melody_part.append(note_obj)

        # Update the chord for the next bar (can be the same or different)
        current_chord_roman = random.choice(mchords)
        current_chord = roman.RomanNumeral(current_chord_roman, key_obj,quarterLength=4.0)

    return score

if __name__ == "__main__":
    random_melody_with_chords = generate_random_melody_with_chords()

    # Show the random melody with chords
    random_melody_with_chords.show()
    random_melody_with_chords.show("midi")
# Out:
#         <div id="midiPlayerDiv24144"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv24144_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv24144");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv24144_play, 2000);
#         } else {
#             midiPlayerDiv24144_play();
#         }
#         </script>
